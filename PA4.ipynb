# %%
#import necessary libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Excel file and refer to it as 'board'
file_path = "board2.xlsx"  # Update with the actual path to the file
board = pd.read_excel("board2.xlsx")
board
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# 13  S14  Female  Microelectronics     Luzon    83           77    89
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 15  S16  Female     Communication     Luzon    71           70    87
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 17  S18    Male     Communication   Visayas    81           40    81
# 18  S19    Male  Microelectronics     Luzon    79           63    79
# 19  S20  Female     Communication  Mindanao    59           60    62
# 20  S21  Female  Microelectronics   Visayas    83           51    68
# 21  S22  Female     Communication   Visayas    64           39    89
# 22  S23    Male   Instrumentation     Luzon    84           70    74
# 23  S24  Female  Microelectronics   Visayas    85           45    60
# 24  S25    Male     Communication     Luzon    74           91    94
# 25  S26  Female   Instrumentation   Visayas    71           47    83
# 26  S27    Male  Microelectronics   Visayas    70           47    40
# 27  S28    Male     Communication   Visayas    85           53    80
# 28  S29    Male   Instrumentation  Mindanao    73           48    71
# 29  S30    Male   Instrumentation     Luzon    78           81    57
#
#     Communication
# 0              78
# 1              52
# 2              57
# 3              68
# 4              88
# 5              83
# 6              48
# 7              53
# 8              42
# 9              44
# 10             67
# 11             64
# 12             43
# 13             73
# 14             86
# 15             81
# 16             45
# 17             52
# 18             71
# 19             85
# 20             72
# 21             58
# 22             47
# 23             41
# 24             42
# 25             62
# 26             86
# 27             53
# 28             62
# 29             56

# %%
# 1a. Create "Instru" DataFrame
# Track is "Instrumentation", Hometown is "Luzon", Electronics > 70
instru_df = df[(df['Track'] == 'Instrumentation') & (df['Hometown'] == 'Luzon') & (df['Electronics'] > 70)][['Name', 'GEAS', 'Electronics']]
instru_df['Track'] = 'Instrumentation'
instru_df['Hometown'] = 'Luzon'

# Display the Instru DataFrame
instru_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 # 1a. Create "Instru" DataFrame
#       2 # Track is "Instrumentation", Hometown is "Luzon", Electronics > 70
# ----> 3 instru_df = df[(df['Track'] == 'Instrumentation') & (df['Hometown'] == 'Luzon') & (df['Electronics'] > 70)][['Name', 'GEAS', 'Electronics']]
#       4 instru_df['Track'] = 'Instrumentation'
#       5 instru_df['Hometown'] = 'Luzon'
#
# NameError: name 'df' is not defined

# %%
# 1b. Create "Mindy" DataFrame
# Hometown is "Mindanao", Gender is "Female", Average >= 55
df['Average'] = (df['Math'] + df['GEAS'] + df['Electronics']) / 3
mindy_df = df[(df['Hometown'] == 'Mindanao') & (df['Gender'] == 'Female') & (df['Average'] >= 55)][['Name', 'Track', 'Electronics', 'Average']]
mindy_df['Gender'] = 'Female'
mindy_df['Hometown'] = 'Mindanao'

# Display the Mindy DataFrame
mindy_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 # 1b. Create "Mindy" DataFrame
#       2 # Hometown is "Mindanao", Gender is "Female", Average >= 55
# ----> 3 df['Average'] = (df['Math'] + df['GEAS'] + df['Electronics']) / 3
#       4 mindy_df = df[(df['Hometown'] == 'Mindanao') & (df['Gender'] == 'Female') & (df['Average'] >= 55)][['Name', 'Track', 'Electronics', 'Average']]
#       5 mindy_df['Gender'] = 'Female'
#
# NameError: name 'df' is not defined

# %%
# Visualize how Track contributes to the average score
plt.figure(figsize=(8,6))
df.groupby('Track')['Average'].mean().plot(kind='bar')
plt.title('Average Grade by Track')
plt.ylabel('Average Grade')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Visualize how Track contributes to the average score
#       2 plt.figure(figsize=(8,6))
# ----> 3 df.groupby('Track')['Average'].mean().plot(kind='bar')
#       4 plt.title('Average Grade by Track')
#       5 plt.ylabel('Average Grade')
#
# NameError: name 'df' is not defined
